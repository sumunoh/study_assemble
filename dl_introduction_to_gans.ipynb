# %% [markdown]
# <a href="https://colab.research.google.com/github/sumunoh/study_assemble/blob/main/dl_introduction_to_gans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://lifeignite.tistory.com/53
#
# https://ysbsb.github.io/gan/2020/06/17/GAN-newbie-guide.html

# %% [markdown]
# GAN 구조는 다음과 같습니다:
# 1. generator 네트워크는 (latent_dim, ) 크기의 벡터를 (32, 32, 3) 크기의 이미지로 매핑합니다.
# 2. discriminator 네트워크는 (32, 32, 3) 크기의 이미지가 진짜일 확률을 추정하여 이진 값으로 매핑합니다.
# 3. 생성자와 판별자를 연결하는 gan 네트워크를 만듭니다. gan(x) = discriminator(generator(x)) 입니다. 이 gan 네트워크는 잠재 공간의 벡터
# 를 판별자의 평가로 매핑합니다. 판별자는 생성자가 잠재 공간의 벡터를 디코딩한 것이 얼마나 현실적인지를 평가합니다.
# 4. "진짜"/"가짜" 레이블과 함께 진짜 이미지와 가짜 이미지 샘플을 사용해 판별자를 훈련합니다. 일반적인 이미지 분류 모델을 훈련하는 것과
# 동일합니다.
# 5. 생성자를 훈련하려면 gan 모델의 손실에 대한 생성자 가중치의 그래디언트를 사용합니다. 이 말은 매 단계마다 생성자에 의해 디코딩된 이
# 미지를 판별자가 “진짜"로 분류하도록 만드는 방향으로 생성자의 가중치를 이동한다는 뜻입니다. 다른 말로하면 판별자를 속이도록 생성자
# 를 훈련합니다.

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.7.0'

# %%
# 생성자

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

latent_dim = 32
height = 32
width = 32
channels = 3

generator_input = keras.Input(shape=(latent_dim,))

# 입력을 16 x 16 크기의 128개 채널을 가진 특성 맵으로 변환
x = layers.Dense(128*16*16)(generator_input)
x = layers.LeakyReLU()(x)
x = layers.Reshape((16,16,128))(x)

# 합성곱 층을 추가
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

# 32 x 32  크기의 업샘플링
x = layers.Conv2DTranspose(256, 4, strides=2, padding='same')(x)
x = layers.LeakyReLU()(x)

# 합성곱 층을 더 추가
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

# 32 x 32 크기의 1개 채널을 가진 특성 맵을 생성
x = layers.Conv2D(channels, 7, activation='tanh', padding='same')(x)
generator = keras.models.Model(generator_input, x)
generator.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32)]              0
#
#  dense (Dense)               (None, 32768)             1081344
#
#  leaky_re_lu (LeakyReLU)     (None, 32768)             0
#
#  reshape (Reshape)           (None, 16, 16, 128)       0
#
#  conv2d (Conv2D)             (None, 16, 16, 256)       819456
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 16, 16, 256)       0
#
#  conv2d_transpose (Conv2DTra  (None, 32, 32, 256)      1048832
#  nspose)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 32, 32, 256)       0
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 256)       1638656
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 32, 32, 256)       0
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 256)       1638656
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 32, 32, 256)       0
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 3)         37635
#
# =================================================================
# Total params: 6,264,579
# Trainable params: 6,264,579
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 판별자

discriminator_input = layers.Input(shape=(height, width, channels))
x = layers.Conv2D(128,3)(discriminator_input)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128,4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128,4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128,4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Flatten()(x)

x = layers.Dropout(0.4)(x)

# 분류 층
x = layers.Dense(1, activation='sigmoid')(x)

discriminator = keras.models.Model(discriminator_input, x)
discriminator.summary()

discriminator_optimizer = keras.optimizers.RMSprop(learning_rate=0.0008, clipvalue=1.0, decay=1e-8)
discriminator.compile(optimizer=discriminator_optimizer, loss='binary_crossentropy')
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_4 (Conv2D)           (None, 30, 30, 128)       3584
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 30, 30, 128)       0
#
#  conv2d_5 (Conv2D)           (None, 14, 14, 128)       262272
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 14, 14, 128)       0
#
#  conv2d_6 (Conv2D)           (None, 6, 6, 128)         262272
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 6, 6, 128)         0
#
#  conv2d_7 (Conv2D)           (None, 2, 2, 128)         262272
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 2, 2, 128)         0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 790,913
# Trainable params: 790,913
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 판별자의 가중치가 훈련되지 않도록 설정 
#(생성자만 업데이트되서 점점 진짜와 구분안되는 데이터 생성하게 해야함)

discriminator.trainable = False
gan_input = keras.Input(shape=(latent_dim,))
gan_output = discriminator(generator(gan_input))
gan = keras.models.Model(gan_input, gan_output)

gan_optimizer = keras.optimizers.RMSprop(learning_rate=0.0004, clipvalue=1.0, decay=1e-8)
gan.compile(optimizer=gan_optimizer, loss='binary_crossentropy')

# %%
import os
from tensorflow.keras.preprocessing import image
(x_train,y_train),(_,_) = keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 11s 0us/step
# 170508288/170498071 [==============================] - 11s 0us/step

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
import pandas as pd
pd.DataFrame(y_train).value_counts()
# Out:
# 9    5000
# 8    5000
# 7    5000
# 6    5000
# 5    5000
# 4    5000
# 3    5000
# 2    5000
# 1    5000
# 0    5000
# dtype: int64

# %%
x_train = x_train[y_train.flatten()==6]

# %%
x_train = x_train.reshape(
    (x_train.shape[0],) + (height, width, channels)).astype('float32')/255.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,8))
for i in range(10):
  plt.subplot(2,5,i+1)
  plt.imshow(x_train[i])
  plt.xticks([])
  plt.yticks([])
plt.show()
plt.close()

# %%
os.mkdir('./datasets')

# %%
iterations = 10000
batch_size = 20
save_dir = './datasets/gan_images/'
if not os.path.exists(save_dir):
  os.mkdir(save_dir)

start = 0
for step in range(iterations):
  # 잠재 공간에서 무작위로 포인트를 샘플링
  random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

  # 가짜 이미지를 디코딩
  generated_images = generator.predict(random_latent_vectors)
  
  # 진짜 이미지와 연결
  stop = start + batch_size
  real_images = x_train[start:stop]
  combined_images = np.concatenate([generated_images, real_images])

  # 진짜와 가짜 이미지를 구분하여 레이블을 합침
  labels = np.concatenate([np.ones((batch_size,1)),
                           np.zeros((batch_size,1))])
  
  # 레이블에 랜덤 노이즈를 추가
  labels += 0.05 * np.random.random(labels.shape)

  # discriminator 훈련
  d_loss = discriminator.train_on_batch(combined_images, labels)

  # 잠재 공간에서 무작위로 포인트 샘플링
  random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

  # 모두 진짜 이미지라고 레이블을 만듬
  misleading_targets = np.zeros((batch_size,1))

  # generator 훈련
  a_loss = gan.train_on_batch(random_latent_vectors, misleading_targets)

  start += batch_size
  if start > len(x_train) - batch_size:
    start = 0

  if step % 100 == 0:
    gan.save_weights('gan.h5')

    print('스탭 %s에서 판별자 손실: %s' % (step,d_loss))
    print('스탭 %s에서 적대적 손실: %s' % (step,a_loss))

    # 생성된 이미지 하나를 저정
    img = image.array_to_img(generated_images[0] * 255., scale=False)
    img.save(os.path.join(save_dir, 'generated_frog' + str(step) + '.png'))

    # 비교를 위하여 진짜 이미지 하나를 저장
    img = image.array_to_img(real_images[0] * 255., scale=False)
    img.save(os.path.join(save_dir,'real_frog' + str(step)+'.png'))
# Out:
# 스탭 0에서 판별자 손실: 0.6853189468383789
# 스탭 0에서 적대적 손실: 0.6864928007125854
# 스탭 100에서 판별자 손실: 0.6807917356491089
# 스탭 100에서 적대적 손실: 0.7412992715835571
# 스탭 200에서 판별자 손실: 0.7060239911079407
# 스탭 200에서 적대적 손실: 0.751639723777771
# 스탭 300에서 판별자 손실: 0.6981862783432007
# 스탭 300에서 적대적 손실: 0.7316856384277344
# 스탭 400에서 판별자 손실: 0.6955608129501343
# 스탭 400에서 적대적 손실: 0.7449719309806824
# 스탭 500에서 판별자 손실: 0.7001729011535645
# 스탭 500에서 적대적 손실: 0.8402611017227173
# 스탭 600에서 판별자 손실: 0.6952625513076782
# 스탭 600에서 적대적 손실: 1.0666499137878418
# 스탭 700에서 판별자 손실: 0.7006663084030151
# 스탭 700에서 적대적 손실: 0.7498279809951782
# 스탭 800에서 판별자 손실: 0.7179363369941711
# 스탭 800에서 적대적 손실: 0.7313627004623413
# 스탭 900에서 판별자 손실: 0.700269341468811
# 스탭 900에서 적대적 손실: 0.7434109449386597
# 스탭 1000에서 판별자 손실: 0.6919751167297363
# 스탭 1000에서 적대적 손실: 0.7721905708312988
# 스탭 1100에서 판별자 손실: 0.6738384962081909
# 스탭 1100에서 적대적 손실: 0.8139615058898926
# 스탭 1200에서 판별자 손실: 0.7085862159729004
# 스탭 1200에서 적대적 손실: 0.7662676572799683
# 스탭 1300에서 판별자 손실: 0.6938995122909546
# 스탭 1300에서 적대적 손실: 0.7596451044082642
# 스탭 1400에서 판별자 손실: 0.6787203550338745
# 스탭 1400에서 적대적 손실: 0.7776429653167725
# 스탭 1500에서 판별자 손실: 0.6860924959182739
# 스탭 1500에서 적대적 손실: 0.8097039461135864
# 스탭 1600에서 판별자 손실: 0.7036800384521484
# 스탭 1600에서 적대적 손실: 0.7305021286010742
# 스탭 1700에서 판별자 손실: 0.7006254196166992
# 스탭 1700에서 적대적 손실: 0.7393686175346375
# 스탭 1800에서 판별자 손실: 0.7118709087371826
# 스탭 1800에서 적대적 손실: 0.7570171356201172
# 스탭 1900에서 판별자 손실: 0.7097518444061279
# 스탭 1900에서 적대적 손실: 0.7625048160552979
# 스탭 2000에서 판별자 손실: 0.6878184676170349
# 스탭 2000에서 적대적 손실: 0.7292755246162415
# 스탭 2100에서 판별자 손실: 0.7008401155471802
# 스탭 2100에서 적대적 손실: 0.7396219372749329
# 스탭 2200에서 판별자 손실: 0.7328925728797913
# 스탭 2200에서 적대적 손실: 0.7503679394721985
# 스탭 2300에서 판별자 손실: 0.6903986930847168
# 스탭 2300에서 적대적 손실: 0.7508584260940552
# 스탭 2400에서 판별자 손실: 0.7036188840866089
# 스탭 2400에서 적대적 손실: 0.7746385931968689
# 스탭 2500에서 판별자 손실: 0.7059729099273682
# 스탭 2500에서 적대적 손실: 0.7503712773323059
# 스탭 2600에서 판별자 손실: 0.6830559968948364
# 스탭 2600에서 적대적 손실: 0.7805767059326172
# 스탭 2700에서 판별자 손실: 0.6811583042144775
# 스탭 2700에서 적대적 손실: 0.7273375988006592
# 스탭 2800에서 판별자 손실: 0.6948366165161133
# 스탭 2800에서 적대적 손실: 0.7745428085327148
# 스탭 2900에서 판별자 손실: 0.700440526008606
# 스탭 2900에서 적대적 손실: 0.7715445756912231
# 스탭 3000에서 판별자 손실: 0.6946021318435669
# 스탭 3000에서 적대적 손실: 0.745693027973175
# 스탭 3100에서 판별자 손실: 0.692397952079773
# 스탭 3100에서 적대적 손실: 0.7276099920272827
# 스탭 3200에서 판별자 손실: 0.687033474445343
# 스탭 3200에서 적대적 손실: 0.7910349369049072
# 스탭 3300에서 판별자 손실: 0.7041590213775635
# 스탭 3300에서 적대적 손실: 0.8077316284179688
# 스탭 3400에서 판별자 손실: 0.9352699518203735
# 스탭 3400에서 적대적 손실: 0.7936239242553711
# 스탭 3500에서 판별자 손실: 0.7021827101707458
# 스탭 3500에서 적대적 손실: 0.744330108165741
# 스탭 3600에서 판별자 손실: 0.6915869116783142
# 스탭 3600에서 적대적 손실: 0.7835217714309692
# 스탭 3700에서 판별자 손실: 0.6934353113174438
# 스탭 3700에서 적대적 손실: 0.7243847250938416
# 스탭 3800에서 판별자 손실: 0.695313572883606
# 스탭 3800에서 적대적 손실: 0.7512235045433044
# 스탭 3900에서 판별자 손실: 0.8409081697463989
# 스탭 3900에서 적대적 손실: 0.7569806575775146
# 스탭 4000에서 판별자 손실: 0.6970160603523254
# 스탭 4000에서 적대적 손실: 0.7517784237861633
# 스탭 4100에서 판별자 손실: 0.6897191405296326
# 스탭 4100에서 적대적 손실: 0.652419924736023
# 스탭 4200에서 판별자 손실: 0.686927080154419
# 스탭 4200에서 적대적 손실: 0.7496774792671204
# 스탭 4300에서 판별자 손실: 0.6905382871627808
# 스탭 4300에서 적대적 손실: 0.7575697898864746
# 스탭 4400에서 판별자 손실: 0.7227414846420288
# 스탭 4400에서 적대적 손실: 0.7235494256019592
# 스탭 4500에서 판별자 손실: 0.7120652198791504
# 스탭 4500에서 적대적 손실: 0.7309325337409973
# 스탭 4600에서 판별자 손실: 0.6854538917541504
# 스탭 4600에서 적대적 손실: 0.7276066541671753
# 스탭 4700에서 판별자 손실: 0.699244499206543
# 스탭 4700에서 적대적 손실: 0.7712867259979248
# 스탭 4800에서 판별자 손실: 0.711898922920227
# 스탭 4800에서 적대적 손실: 0.7702968716621399
# 스탭 4900에서 판별자 손실: 0.6916290521621704
# 스탭 4900에서 적대적 손실: 0.7720851898193359
# 스탭 5000에서 판별자 손실: 0.7072210311889648
# 스탭 5000에서 적대적 손실: 0.6950174570083618
# 스탭 5100에서 판별자 손실: 0.6799163818359375
# 스탭 5100에서 적대적 손실: 0.7267605066299438
# 스탭 5200에서 판별자 손실: 0.7028851509094238
# 스탭 5200에서 적대적 손실: 0.7733362317085266
# 스탭 5300에서 판별자 손실: 0.6909838318824768
# 스탭 5300에서 적대적 손실: 0.8198674321174622
# 스탭 5400에서 판별자 손실: 0.7035629749298096
# 스탭 5400에서 적대적 손실: 0.7811287641525269
# 스탭 5500에서 판별자 손실: 0.6864570379257202
# 스탭 5500에서 적대적 손실: 0.7755851149559021
# 스탭 5600에서 판별자 손실: 0.6867563128471375
# 스탭 5600에서 적대적 손실: 0.7364642024040222
# 스탭 5700에서 판별자 손실: 0.686015248298645
# 스탭 5700에서 적대적 손실: 1.0969196557998657
# 스탭 5800에서 판별자 손실: 0.6921173334121704
# 스탭 5800에서 적대적 손실: 0.9143707156181335
# 스탭 5900에서 판별자 손실: 0.6784940361976624
# 스탭 5900에서 적대적 손실: 0.8220597505569458
# 스탭 6000에서 판별자 손실: 0.6705433130264282
# 스탭 6000에서 적대적 손실: 0.7940061092376709
# 스탭 6100에서 판별자 손실: 0.6656118631362915
# 스탭 6100에서 적대적 손실: 0.77252197265625
# 스탭 6200에서 판별자 손실: 0.7064955234527588
# 스탭 6200에서 적대적 손실: 0.7818461060523987
# 스탭 6300에서 판별자 손실: 0.7090945243835449
# 스탭 6300에서 적대적 손실: 0.9647232294082642
# 스탭 6400에서 판별자 손실: 0.6831296682357788
# 스탭 6400에서 적대적 손실: 0.829506516456604
# 스탭 6500에서 판별자 손실: 0.6787741780281067
# 스탭 6500에서 적대적 손실: 0.9487050771713257
# 스탭 6600에서 판별자 손실: 0.6793180704116821
# 스탭 6600에서 적대적 손실: 0.7468447685241699
# 스탭 6700에서 판별자 손실: 0.7067283987998962
# 스탭 6700에서 적대적 손실: 0.8335413932800293
# 스탭 6800에서 판별자 손실: 0.6890956163406372
# 스탭 6800에서 적대적 손실: 0.7702022790908813
# 스탭 6900에서 판별자 손실: 0.710111141204834
# 스탭 6900에서 적대적 손실: 0.7630380392074585
# 스탭 7000에서 판별자 손실: 0.6889541745185852
# 스탭 7000에서 적대적 손실: 0.7130042314529419
# 스탭 7100에서 판별자 손실: 0.6775408387184143
# 스탭 7100에서 적대적 손실: 0.7586382031440735
# 스탭 7200에서 판별자 손실: 0.6762403249740601
# 스탭 7200에서 적대적 손실: 0.9563027620315552
# 스탭 7300에서 판별자 손실: 0.7417548894882202
# 스탭 7300에서 적대적 손실: 0.9552921056747437
# 스탭 7400에서 판별자 손실: 0.6954178810119629
# 스탭 7400에서 적대적 손실: 0.7142149209976196
# 스탭 7500에서 판별자 손실: 0.6686909794807434
# 스탭 7500에서 적대적 손실: 0.8302534222602844
# 스탭 7600에서 판별자 손실: 0.638188362121582
# 스탭 7600에서 적대적 손실: 0.6391419172286987
# 스탭 7700에서 판별자 손실: 0.6892501711845398
# 스탭 7700에서 적대적 손실: 0.8373463749885559
# 스탭 7800에서 판별자 손실: 0.7151453495025635
# 스탭 7800에서 적대적 손실: 1.2015554904937744
# 스탭 7900에서 판별자 손실: 0.6919514536857605
# 스탭 7900에서 적대적 손실: 0.8816734552383423
# 스탭 8000에서 판별자 손실: 0.6612741351127625
# 스탭 8000에서 적대적 손실: 0.9164922833442688
# 스탭 8100에서 판별자 손실: 0.7441784143447876
# 스탭 8100에서 적대적 손실: 1.2530397176742554
# 스탭 8200에서 판별자 손실: 0.6904439926147461
# 스탭 8200에서 적대적 손실: 0.7480869293212891
# 스탭 8300에서 판별자 손실: 0.6670037508010864
# 스탭 8300에서 적대적 손실: 0.7077496647834778
# 스탭 8400에서 판별자 손실: 0.7013214826583862
# 스탭 8400에서 적대적 손실: 1.0709846019744873
# 스탭 8500에서 판별자 손실: 0.6847183108329773
# 스탭 8500에서 적대적 손실: 0.804360568523407
# 스탭 8600에서 판별자 손실: 0.6916928291320801
# 스탭 8600에서 적대적 손실: 0.7194147109985352
# 스탭 8700에서 판별자 손실: 0.6957622170448303
# 스탭 8700에서 적대적 손실: 0.7620335817337036
# 스탭 8800에서 판별자 손실: 0.685404360294342
# 스탭 8800에서 적대적 손실: 0.8061253428459167
# 스탭 8900에서 판별자 손실: 0.673529863357544
# 스탭 8900에서 적대적 손실: 0.6777595281600952
# 스탭 9000에서 판별자 손실: 0.6661674380302429
# 스탭 9000에서 적대적 손실: 0.8431035280227661
# 스탭 9100에서 판별자 손실: 0.6640555262565613
# 스탭 9100에서 적대적 손실: 0.7085205316543579
# 스탭 9200에서 판별자 손실: 0.7007818818092346
# 스탭 9200에서 적대적 손실: 0.8354543447494507
# 스탭 9300에서 판별자 손실: 0.713800311088562
# 스탭 9300에서 적대적 손실: 0.826276957988739
# 스탭 9400에서 판별자 손실: 0.6776790618896484
# 스탭 9400에서 적대적 손실: 0.8016241788864136
# 스탭 9500에서 판별자 손실: 0.6733137965202332
# 스탭 9500에서 적대적 손실: 0.9854992628097534
# 스탭 9600에서 판별자 손실: 0.670598030090332
# 스탭 9600에서 적대적 손실: 0.7590018510818481
# 스탭 9700에서 판별자 손실: 0.6890238523483276
# 스탭 9700에서 적대적 손실: 0.8244674801826477
# 스탭 9800에서 판별자 손실: 0.6764616966247559
# 스탭 9800에서 적대적 손실: 0.8017606735229492
# 스탭 9900에서 판별자 손실: 0.6993656158447266
# 스탭 9900에서 적대적 손실: 0.7740689516067505

# %%
# 가짜 이미지 몇개를 출력

random_latent_vectors = np.random.normal(size=(10,latent_dim))
generated_images = generator.predict(random_latent_vectors)
plt.figure(figsize=(20,8))
for i in range(generated_images.shape[0]):
  plt.subplot(2,5,i+1)
  img = image.array_to_img(generated_images[i] * 255., scale=False)
  plt.imshow(img)
  plt.xticks([])
  plt.yticks([])
plt.show()
plt.close()
